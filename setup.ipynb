# %%
import sys
print(sys.executable)
# Out:
# c:\Users\josep\miniconda3\envs\bsd\python.exe

# %%
# !{sys.executable} -m pip list
# Out:
# Package                   Version
# ------------------------- --------------------
# about-time                4.2.1
# addict                    2.4.0
# alive-progress            3.1.5
# asgiref                   3.7.2
# asttokens                 2.4.1
# attrs                     23.1.0
# autograd                  1.6.2
# Brotli                    1.1.0
# certifi                   2023.11.17
# charset-normalizer        3.2.0
# cma                       3.2.2
# colorama                  0.4.6
# coloredlogs               15.0.1
# comm                      0.1.4
# comtypes                  1.2.0
# contourpy                 1.1.1
# cycler                    0.11.0
# debugpy                   1.8.0
# decorator                 5.1.1
# defusedxml                0.7.1
# Deprecated                1.2.14
# dill                      0.3.7
# Django                    4.2.5
# dxcam                     0.0.5
# EasyProcess               1.1
# entrypoint2               1.1
# ...

# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- --------------------
# about-time                4.2.1
# addict                    2.4.0
# alive-progress            3.1.5
# asgiref                   3.7.2
# asttokens                 2.4.1
# attrs                     23.1.0
# autograd                  1.6.2
# Brotli                    1.1.0
# certifi                   2023.11.17
# charset-normalizer        3.2.0
# cma                       3.2.2
# colorama                  0.4.6
# coloredlogs               15.0.1
# comm                      0.1.4
# comtypes                  1.2.0
# contourpy                 1.1.1
# cycler                    0.11.0
# debugpy                   1.8.0
# decorator                 5.1.1
# defusedxml                0.7.1
# Deprecated                1.2.14
# dill                      0.3.7
# Django                    4.2.5
# dxcam                     0.0.5
# EasyProcess               1.1
# entrypoint2               1.1
# ...

# %%
# !pip install ultralytics
